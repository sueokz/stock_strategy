# %%
#!pip install yfinance -U
#https://qiita.com/XKAB/items/5fc0ee13f77d89696e83
#!pip install ta

import requests
import datetime
from datetime import datetime
import time
import pandas as pd
from bs4 import BeautifulSoup
import re
import asyncio
import yfinance as yf
import numpy as np
import ta
import matplotlib.pyplot as plt

# %%
# csvの成型
# csvの読み込み
df = pd.read_csv("gyouseki.csv")
prime_df = pd.read_csv("prime.csv")

# 時価総額を見やすく
df['時価総額'] = df['時価総額'].apply(lambda x: float(x.replace('百万円', '').replace('$', '').replace(',', '')) if isinstance(x, str) else x)
df = df.rename(columns={'時価総額': '時価総額(百万円)'})


# 条件抽出とcsv化
filtered_df = (df['時価総額(百万円)'] >= 100000)
filtered_df
filtered_df.to_csv("filtered.csv")


# 'symbol'列をキーにしてデータを結合する
merged_df = pd.merge(prime_df, df, on='symbol')

# 結合したデータをCSVファイルに保存
merged_df.to_csv("merged_data.csv", index=False)

#　余分な列を消す
df = pd.read_csv("merged_data.csv")
df = df.drop("Unnamed: 0_x", axis=1)
df = df.drop("Unnamed: 0_y", axis=1)
df.to_csv("merged_data.csv", index=False, mode='w')

# %%
#銘柄コードを取得
df_find_symbol = pd.read_csv("filtered.csv")
code_list=df_find_symbol["symbol"]
code_list

#今日の日付のcsv
dt = datetime.datetime.today() 
print(dt) 
d = dt.date()
print(d)
today="buy_list"+ str(d) +".csv"
print(today)

#昨日のcsvと銘柄
from datetime import date, timedelta
yesterday = datetime.datetime.today()  - timedelta(days=1)
d_y = yesterday.date()
print(d_y)

try:
    df = pd.read_csv("buy_list" + str(d_y) + ".csv")
    buy_yesterday = df["symbol"]
    print(buy_yesterday)
except FileNotFoundError:
    print("ファイルが見つかりませんでした。続行します。")
    buy_yesterday = []
# Out:
# 2024-04-02 16:15:12.908488
# 2024-04-02
# buy_list2024-04-02.csv
# 2024-04-01
# ファイルが見つかりませんでした。続行します。

# %%
#非同期処理、func1が今日の銘柄。func2が昨日の銘柄の確認
buy_list = []
async def func1():
    print('func1() started')
    for i in code_list:
        
        #条件

        # 直近2日間のシグナルが連続で"Buy"の場合に購入リストに追加
        if len(df) >= 2 and df["signal_1"].iloc[-1] == "OK" and df["signal_1"].iloc[-2] == "OK" and df["signal_2"].iloc[-1]:
            buy_list.append(i)

        await asyncio.sleep(0.1)




async def func2():
    if buy_yesterday:
        print('func2() started')
        for i in buy_yesterday:
            
　　　　#条件の確認　　　　
            if '' in df.columns:
                if df[''].iloc[-1] > :
                    print("利確サインの出現")
                else:
                    print("まだサインは出ていません")
            else:
                print("列が存在しません。")
    else:
        print("昨日のサイン銘柄が存在しません。")

async def main():
    task1 = asyncio.create_task(func1())
    task2 = asyncio.create_task(func2())
    await task1
    await task2
    print(buy_list)

await main()
# Out:
# func1() started
# [*********************100%%**********************]  1 of 1 completed
# func2() started
# [*********************100%%**********************]  1 of 1 completed
# 銘柄コード2109
# 利確は3203.3
# 2109
# 3.86 %
# 利確は15114.6
# まだサインは出ていません
# [*********************100%%**********************]  1 of 1 completed
# 銘柄コード3391
# 利確は11082.8
# 3391
# 2.42 %
# 利確は11082.8
# まだサインは出ていません
# [*********************100%%**********************]  1 of 1 completed
# 銘柄コード6407
# 利確は3078.67
# 6407
# 2.97 %
# 利確は3078.67
# まだサインは出ていません
# [*********************100%%**********************]  1 of 1 completed
# 銘柄コード9101
# 利確は4168.41
# 9101
# 12.85 %
# 利確は56050.95
# まだサインは出ていません
# [*********************100%%**********************]  1 of 1 completed
# 銘柄コード9107
# 利確は2068.24
# 9107
# 6.66 %
# 利確は15381.28
# まだサインは出ていません
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# ...

# %%
#今日の銘柄をまとめておく

# merged_csvからデータを読み込む
merged_csv = pd.read_csv("merged_data.csv")

# buy_listの銘柄コードをセットに変換して重複を除外する
buy_list_unique = set(buy_list)

# merged_csvからbuy_listに含まれる銘柄のデータを抽出する
today_data = merged_csv[merged_csv['symbol'].isin(buy_list_unique)]

# 抽出したデータをCSVファイルに保存する
today_data.to_csv("today.csv", index=False)

# 抽出したデータをCSVファイルに保存する
today_data.to_csv(today + ".csv", index=False)
today_data
# Out:
#       symbol              name 前日終値（03/21）         始値         高値         安値  \
# 91      2109    ＤＭ三井製糖ホールディングス    3,380.0円   3,370.0円   3,370.0円   3,305.0円
# 313     3360  シップヘルスケアホールディングス    2,228.0円   2,248.0円   2,278.5円   2,227.0円
# 318     3391       ツルハホールディングス   11,490.0円  11,000.0円  11,270.0円  10,900.0円
# 470     4151             協和キリン    2,845.0円   2,828.0円   2,848.5円   2,795.0円
# 1495    9101              日本郵船    4,226.0円   4,230.0円   4,272.0円   4,206.0円
# 1497    9107              川崎汽船    6,291.0円   6,340.0円   6,411.0円   6,295.0円
# 1498    9110        ＮＳユナイテッド海運    5,130.0円   5,110.0円   5,130.0円   5,080.0円
#
#       配当利回り  単元株数     PER    PSR    PBR          出来高          時価総額      発行済株数  \
# 91    3.62%  100株  13.50倍  0.66倍  1.00倍     130,300株    108,037百万円   32,639千株
# 313   2.15%  100株  17.45倍  0.39倍  1.77倍     221,800株    226,824百万円  101,669千株
# 318   2.40%  100株  21.35倍  0.56倍  1.98倍     361,500株    549,784百万円   49,507千株
# ...

# %%
#buy_listにも追加

# 現在の日付を取得
today = datetime.today().strftime('%Y-%m-%d')

# 既存のCSVファイルを読み込むか、新しいデータフレームを作成する
try:
    existing_data = pd.read_csv("buy_list.csv")
except FileNotFoundError:
    existing_data = pd.DataFrame()

# 新しい行を作成して日付を追加
new_row = pd.DataFrame({"date": today}, index=[0])

# 新しいデータフレームに結合
existing_data = pd.concat([new_row, existing_data], ignore_index=True)

# 結果をCSVに保存
existing_data.to_csv("buy_list.csv", index=False)
